# %%
import langchain

langchain.__version__
# Out:
# '1.3.11'

# %%
import os

os.chdir("..")

# %%
from api.services.roleplay_service import RoleplayService
from IPython.display import Image, display

agent = RoleplayService().graph
display(Image(agent.get_graph(xray=True).draw_mermaid_png()))
